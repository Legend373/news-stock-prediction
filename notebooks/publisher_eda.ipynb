# %%
import sys
import os
import pandas as pd


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.eda.publisher_analysis import (
    top_publishers,
    publisher_article_distribution,
    extract_email_domains,
    publisher_news_type
)

# %%
# Top 10 publishers by article count
df = pd.read_csv("../data/raw_analyst_ratings.csv")
top10 = top_publishers(df)
top10
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
top10.plot(kind="bar", figsize=(12,5), title="Top 10 Publishers by Article Count")
# Out:
# <Axes: title={'center': 'Top 10 Publishers by Article Count'}, xlabel='publisher'>

# %%
all_counts = publisher_article_distribution(df)
all_counts.head(15)  # show top 15
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Vick Meyer            24826
# webmaster             20313
# Benzinga_Newsdesk     19410
# Zacks                 19390
# Jayson Derrick        19050
# Name: count, dtype: int64

# %%
domain_counts = extract_email_domains(df)
domain_counts.head(10)
# Out:
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64

# %%
publisher_news = publisher_news_type(df)
publisher_news.head(5)
# Out:
#           publisher                                           headline
# 0        47ertrends  Saturday, February 18, 2012 Stock Market Trend...
# 1              AARP  3 Ways Small Businesses Can Get Emergency Help...
# 2       ABNNewswire  BPH Energy Limited (ASX:BPH): Swinburne Univer...
# 3             Aakin  Sony Ups The Ante With Its Latest dSLR Offerin...
# 4  Aaron Jackson.Ed  The Top Things I've Read This Week | The Best ...
