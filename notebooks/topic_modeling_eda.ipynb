# %%
import sys
import os
import pandas as pd


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.nlp.topic_modeling import (
    preprocess_text,
    extract_keywords,
    perform_lda_topic_modeling
)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\YASMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("../data/raw_analyst_ratings.csv")
df = preprocess_text(df, "headline")
df[["headline", "clean_headline"]].head()
# Out:
#                                             headline  \
# 0            Stocks That Hit 52-Week Highs On Friday
# 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                      71 Biggest Movers From Friday
# 3       46 Stocks Moving In Friday's Mid-Day Session
# 4  B of A Securities Maintains Neutral on Agilent...
#
#                                       clean_headline
# 0               stocks that hit week highs on friday
# 1            stocks that hit week highs on wednesday
# 2                         biggest movers from friday
# 3            stocks moving in fridays midday session
# 4  b of a securities maintains neutral on agilent...

# %%
keywords = extract_keywords(df)
keywords
# Out:
#        keyword   count
# 18          vs  162147
# 14      stocks  161868
# 6          est  140606
# 5          eps  128929
# 13      shares  114209
# 11     reports  108707
# 17      update   91680
# 7       market   90880
# 4     earnings   87185
# 12       sales   79526
# 15         top   78678
# 9           pt   73054
# 19        week   67669
# 0    announces   66529
# 8        price   64232
# 2          buy   64060
# 3   downgrades   61942
# 16     trading   61158
# 1    benzingas   57985
# 10      raises   57798

# %%
keywords.plot.bar(x="keyword", y="count", figsize=(10,5), title="Top Keywords in News Headlines")
# Out:
# <Axes: title={'center': 'Top Keywords in News Headlines'}, xlabel='keyword'>
